# %%
# The code was removed by DSX for sharing.
# Out:
# Loading required package: httr
# Loading required package: RCurl
# Loading required package: bitops
#
# Attaching package: ‘RCurl’
#
# The following object is masked from ‘package:SparkR’:
#
#     base64
#   household age_husband age_wife income_husband income_wife bedrooms
# 1   48      64          62        11000         29200       1
# 2  218      63          64       100000          3100       4
# 3  279      56          51        31000             0       2
# 4  612      71          68        51700          8800       3
# 5  947      37          33        16600         26000       3
# 6 1373      86          91        77500         30000       4
#   electricity gas number_children internet mode     own
# 1  90          3  0               Yes      followup Owned with mortgage or loan
# 2 230         30  0               Yes      mail     Owned with mortgage or loan
# 3 200         40  0               No       followup Rented
# 4 170          3  0               Yes      internet Owned free and clear
# 5 260          3  2               Yes      internet Owned with mortgage or loan
# 6  20         30  0               Yes      internet Owned free and clear
#   language     decade_built
# 1 English only 1940
# 2 English only 1990
# 3 English only 1950
# 4 English only 1950
# 5 English only 1990
# 6 English only 1980

# %%
counts <- table(acs$bedrooms)
barplot(counts, main="Bedrooms Distribution",  xlab="Number of Bedrooms")
